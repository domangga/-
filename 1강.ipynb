# %% [markdown]
# Numbers

# %%
1+1
# Out:
# 2

# %%
1*3
# Out:
# 3

# %%
1/2
# Out:
# 0.5

# %%
2 ** 4
# Out:
# 16

# %%
4%2
# Out:
# 0

# %%
5%2
# Out:
# 1

# %%
(2+3) * (5+5)
# Out:
# 125

# %% [markdown]
# 변수 대입

# %%
# can nor start with number or special characters
# 변수는 숫자나 특수문자로 시작할수 없다.
name_of_var = 2

# %%
x = 2
y = 3

# %%
z = x + y

# %%
z
# Out:
# 5

# %%
1/2
# python 나누기
# Out:
# 0.5

# %%
2**4
# 2의 4승
# Out:
# 16

# %% [markdown]
# String

# %%
'single quotes'
# 단따옴표
# Out:
# 'single quotes'

# %%
"double quotes"
# 쌍따옴표
# Out:
# 'double quotes'

# %%
" wrap lot's of other quotes"
# 파이선에서는 space를 문자로 인식한다.
# Out:
# " wrap lot's of other quotes"

# %% [markdown]
# # Data Type
# numbers

# %% [markdown]
# printing

# %%
x='hello'

# %%
x
# Out:
# 'hello'

# %%
print(x)
# Out:
# hello

# %%
num = 12
name = 'sam'

# %%
print('my number is: {one}my name is: {two}'.format(one=num,two=name))
# Out:
# my number is: 12my name is: sam

# %%
print('my number is:{},and my name is : {}'.format(num,name))
# Out:
# my number is:12,and my name is : sam

# %%
num1 = 18
namel = 'jeayoung'

# %%
print("나이는 : {one},그리고 이름은 :{two}".format(one = num1,two = namel))
# Out:
# 나이는 : 18,그리고 이름은 :jeayoung

# %%
print("나이는 : {},그리고 이름은 :{}".format(num1,namel))
# Out:
# 나이는 : 18,그리고 이름은 :jeayoung

# %% [markdown]
# Lists

# %%
[1,2,3]
# Out:
# [1, 2, 3]

# %%
['hi',1,[1,2]]
# Out:
# ['hi', 1, [1, 2]]

# %%
my_list = ['a','b','c','d']

# %%
my_list.append('d')

# %%
my_list
# Out:
# ['a', 'b', 'c']

# %%
my_list[0]
# Out:
# 'a'

# %%
my_list[1]
# Out:
# 'b'

# %%
my_list[:]
# Out:
# ['a', 'b', 'c', 'd']

# %%
my_list[0]
# Out:
# 'a'

# %%
my_list[1]
# Out:
# 'b'

# %%
my_list[1:]
# Out:
# ['b', 'c', 'd']

# %%
my_list[:1]
# Out:
# ['a']

# %%
my_list[0]= "NEW"

# %%
my_list
# Out:
# ['NEW', 'b', 'c', 'd']

# %%
nest =[1,2,3,[4,5,['target']]]

# %%
nest[3]
# Out:
# [4, 5, ['target']]

# %%
nest [3][2]
# Out:
# ['target']

# %%
nest[3][2][0]
# Out:
# 'target'
